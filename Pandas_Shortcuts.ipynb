# %% [markdown]
# # Pandas Shortcuts

# %% [markdown]
# ### Import libraries and aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import file

# %%
sales = pd.read_csv("https://raw.githubusercontent.com/e55010104110/hello-world/master/Financial_Sample.csv")

# Import other file types:
# pd.read_table
# pd.read_excel
# pd.read_json
# pd.read_html
# pd.read_xml
# pd.read_sql

# %% [markdown]
# ### Import file with parameters (index, header, parse dates, etc)

# %%
sales_structured = pd.read_csv("https://raw.githubusercontent.com/e55010104110/hello-world/master/Financial_Sample.csv",
                               header='infer',
                               index_col=None,
                               parse_dates=True
                              )

# %% [markdown]
# ### Export DF to file

# %%
# sales_structured.to_excel("sales_structured.xlsx", sheet_name="sales", index=False)
# Export to other types
# df.to_csv
# df.to_dict
# df.to_html
# df.to_json
# df.to_sql

# %% [markdown]
# ### Connect to SQL server

# %%
# !pip install pyodbc

# %%
# import pyodbc

# %%
# driver= '{SQL Server Native Client 11.0}'

#cnxn = pyodbc.connect(
#    Trusted_Connection='Yes',
#    Driver='{SQL Server}',
#    Server='amsanalytics.auth.hpicorp.net,1433',
#    Database='amsanalytics'
#)

# %%
#UTILS = pd.read_sql_query('SELECT * FROM UTILS_Calendar',cnxn)

# %%
#UTILS.head()

# %% [markdown]
# ### Connect to PostgreSQL server

# %%
"""
import psycopg2

# Connection parameters, yours will be different
param_dic = {
    "host"      : "localhost",
    "database"  : "globaldata",
    "user"      : "myuser",
    "password"  : "Passw0rd"
}

def connect(params_dic):
    # Connect to the PostgreSQL database server
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn
"""
# Out:
# '\nimport psycopg2\n\n# Connection parameters, yours will be different\nparam_dic = {\n    "host"      : "localhost",\n    "database"  : "globaldata",\n    "user"      : "myuser",\n    "password"  : "Passw0rd"\n}\n\ndef connect(params_dic):\n    # Connect to the PostgreSQL database server\n    conn = None\n    try:\n        # connect to the PostgreSQL server\n        print(\'Connecting to the PostgreSQL database...\')\n        conn = psycopg2.connect(**params_dic)\n    except (Exception, psycopg2.DatabaseError) as error:\n        print(error)\n        sys.exit(1) \n    print("Connection successful")\n    return conn\n'

# %%
"""
def postgresql_to_dataframe(conn, select_query, column_names):
    
    # Tranform a SELECT query into a pandas dataframe
    
    cursor = conn.cursor()
    try:
        cursor.execute(select_query)
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        cursor.close()
        return 1
    
    # Naturally we get a list of tupples
    tupples = cursor.fetchall()
    cursor.close()
    
    # We just need to turn it into a pandas dataframe
    df = pd.DataFrame(tupples, columns=column_names)
    return df
"""
# Out:
# '\ndef postgresql_to_dataframe(conn, select_query, column_names):\n    \n    # Tranform a SELECT query into a pandas dataframe\n    \n    cursor = conn.cursor()\n    try:\n        cursor.execute(select_query)\n    except (Exception, psycopg2.DatabaseError) as error:\n        print("Error: %s" % error)\n        cursor.close()\n        return 1\n    \n    # Naturally we get a list of tupples\n    tupples = cursor.fetchall()\n    cursor.close()\n    \n    # We just need to turn it into a pandas dataframe\n    df = pd.DataFrame(tupples, columns=column_names)\n    return df\n'

# %% [markdown]
# ### Create DF from list

# %%
lst = ['This', 'is', 'a', 'list', 'that', 'will', 'become', 'a','dataframe']
  
df_from_list = pd.DataFrame(lst, index =['a', 'b', 'c', 'd', 'e', 'f', 'g','h','i'], columns =['Column Name'])
df_from_list
# Out:
#   Column Name
# a        This
# b          is
# c           a
# d        list
# e        that
# f        will
# g      become
# h           a
# i   dataframe

# %% [markdown]
# ### Create DF from dictionary

# %%
df_from_dict = pd.DataFrame(
    {
        "Column_1": ["Braund, Mr. Owen Harris", "Allen, Mr. William Henry","Bonnell, Miss. Elizabeth"],
        "Column_2": [22, 35, 58],
        "Column_3": ["male", "male", "female"],
    }
)
df_from_dict
# Out:
#                    Column_1  Column_2 Column_3
# 0   Braund, Mr. Owen Harris        22     male
# 1  Allen, Mr. William Henry        35     male
# 2  Bonnell, Miss. Elizabeth        58   female

# %% [markdown]
# ### Reset DF after changes in file or database

# %%
# Note: this method does NOT return a new DataFrame.
# The updating is done to the original DataFrame.

df1 = pd.DataFrame([["Emil", "Tobias", "Linus"], [16, 14, 10]])
df2 = pd.DataFrame([["Emil"], [17]])

df1.update(df2)
df1
# Out:
#       0       1      2
# 0  Emil  Tobias  Linus
# 1    17      14     10

# %% [markdown]
# ### List columns

# %%
sales_structured.columns
# list(sales_structured.columns)
# Out:
# Index(['Segment', 'Country', 'Product', 'DiscountBand', 'UnitsSold',
#        'ManufacturingPrice', 'SalePrice', 'GrossSales', 'Discounts', 'Sales',
#        'COGS', 'Profit', 'Date', 'MonthNumber', 'MonthName', 'Year'],
#       dtype='object')

# %% [markdown]
# ### List data types

# %%
sales_structured.dtypes
# Out:
# Segment                object
# Country                object
# Product                object
# DiscountBand           object
# UnitsSold             float64
# ManufacturingPrice      int64
# SalePrice               int64
# GrossSales             object
# Discounts              object
# Sales                  object
# COGS                   object
# Profit                 object
# Date                   object
# MonthNumber             int64
# MonthName              object
# Year                    int64
# dtype: object

# %% [markdown]
# ### Summary of the dataframe

# %%
sales_structured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Segment             700 non-null    object
#  1   Country             700 non-null    object
#  2   Product             700 non-null    object
#  3   DiscountBand        700 non-null    object
#  4   UnitsSold           700 non-null    float64
#  5   ManufacturingPrice  700 non-null    int64
#  6   SalePrice           700 non-null    int64
#  7   GrossSales          700 non-null    object
#  8   Discounts           647 non-null    object
#  9   Sales               700 non-null    object
#  10  COGS                700 non-null    object
#  11  Profit              695 non-null    object
#  12  Date                700 non-null    object
#  13  MonthNumber         700 non-null    int64
#  14  MonthName           700 non-null    object
# ...

# %%
# The following code returns a summary: 700 rows and 21 columns
sales_structured.shape
# Out:
# (700, 16)

# %% [markdown]
# ### List size (number of rows)

# %%
sales_structured.size
# Out:
# 11200

# %% [markdown]
# ### List basic statistics

# %%
sales_structured.describe()
# This method will only work with numeric columns
# The attribute df.describe will display the top and bottom rows of the df
# Out:
#          UnitsSold  ManufacturingPrice   SalePrice  MonthNumber         Year
# count   700.000000          700.000000  700.000000   700.000000   700.000000
# mean   1608.294286           96.477143  118.428571     7.900000  2013.750000
# std     867.427859          108.602612  136.775515     3.377321     0.433322
# min     200.000000            3.000000    7.000000     1.000000  2013.000000
# 25%     905.000000            5.000000   12.000000     5.750000  2013.750000
# 50%    1542.500000           10.000000   20.000000     9.000000  2014.000000
# 75%    2229.125000          250.000000  300.000000    10.250000  2014.000000
# max    4492.500000          260.000000  350.000000    12.000000  2014.000000

# %% [markdown]
# ### Apply functions to Series directly or using the df notation

# %%
sales_structured["UnitsSold"].sum()
# Out:
# 1125806.0

# %%
units = sales_structured["UnitsSold"]
units.sum()
# Out:
# 1125806.0

# %% [markdown]
# ### Rename columns

# %%
# Method 1: Rename Specific Columns
sales_structured.rename(columns = {'DiscountBand':'Discount Band', 'GrossSales':'Gross Sales'}, inplace = True)
sales_structured.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'UnitsSold',
#        'ManufacturingPrice', 'SalePrice', 'Gross Sales', 'Discounts', 'Sales',
#        'COGS', 'Profit', 'Date', 'MonthNumber', 'MonthName', 'Year'],
#       dtype='object')

# %%
#Method 2: Rename All Columns
sales_structured.columns = ['segment', 'country', 'product', 'discount band','units sold',
       'manufacturing price', 'sale price', 'gross sales', 'discounts', 'sales',
       'COGS', 'profit', 'date', 'month number', 'month name', 'year']
sales_structured.columns
# Out:
# Index(['segment', 'country', 'product', 'discount band', 'units sold',
#        'manufacturing price', 'sale price', 'gross sales', 'discounts',
#        'sales', 'COGS', 'profit', 'date', 'month number', 'month name',
#        'year'],
#       dtype='object')

# %%
#Method 3: Replace Specific Characters in Columns
sales_structured.columns = sales_structured.columns.str.replace('d', 'D')
sales_structured.columns
# Out:
# Index(['segment', 'country', 'proDuct', 'Discount banD', 'units solD',
#        'manufacturing price', 'sale price', 'gross sales', 'Discounts',
#        'sales', 'COGS', 'profit', 'Date', 'month number', 'month name',
#        'year'],
#       dtype='object')

# %%
# Resetting the column names
sales_structured.columns = ['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
       'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts', 'Sales',
       'COGS', 'Profit', 'Date', 'Month Number', 'Month Name', 'Year']
sales_structured.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %% [markdown]
# ### Replace Characters in Strings in a column

# %%
sales_structured['COGS'] = sales_structured['COGS'].str.replace(',','')
sales_structured['Profit'] = sales_structured['Profit'].str.replace(',','')
sales_structured['Sales'] = sales_structured['Sales'].str.replace(',','')
sales_structured['Discounts'] = sales_structured['Discounts'].str.replace(',','')
sales_structured['Gross Sales'] = sales_structured['Gross Sales'].str.replace(',','')

# %% [markdown]
# ### Change data types of columns

# %%
# Method 1, using df.to_numeric for string to int/float
# sales_structured["Discount Band"] = pd.to_numeric(sales_structured["Discount Band"])

sales_structured["COGS"] = pd.to_numeric(sales_structured["COGS"])
sales_structured["Profit"] = pd.to_numeric(sales_structured["Profit"])
sales_structured.dtypes
# Out:
# Segment                 object
# Country                 object
# Product                 object
# Discount Band           object
# Units Sold             float64
# Manufacturing Price      int64
# Sale Price               int64
# Gross Sales             object
# Discounts               object
# Sales                   object
# COGS                   float64
# Profit                 float64
# Date                    object
# Month Number             int64
# Month Name              object
# Year                     int64
# dtype: object

# %%
# Method 2, using df.astype()
sales_structured = sales_structured.astype({"Sales": 'float64'}, errors='ignore')
sales_structured = sales_structured.astype({"Gross Sales": 'float64'}, errors='ignore')

# %%
sales_structured = sales_structured.astype({"Discounts": 'float64'}, errors='ignore')

# %%
# To change the data type of a Date column, I need to use the format as it is in the data source
sales_structured["Date"] = pd.to_datetime(sales_structured["Date"],format='%m/%d/%Y')
sales_structured.dtypes
# Out:
# Segment                        object
# Country                        object
# Product                        object
# Discount Band                  object
# Units Sold                    float64
# Manufacturing Price             int64
# Sale Price                      int64
# Gross Sales                   float64
# Discounts                     float64
# Sales                         float64
# COGS                          float64
# Profit                        float64
# Date                   datetime64[ns]
# Month Number                    int64
# Month Name                     object
# Year                            int64
# dtype: object

# %% [markdown]
# ### Add a column to dataframe

# %%
sales_structured["Type of Sales"] = "Store"
sales_structured["Type of Sales"]
# Out:
# 0      Store
# 1      Store
# 2      Store
# 3      Store
# 4      Store
#        ...
# 695    Store
# 696    Store
# 697    Store
# 698    Store
# 699    Store
# Name: Type of Sales, Length: 700, dtype: object

# %% [markdown]
# ### Add a calculated column to dataframe

# %%
sales_structured["Discount %"] = sales_structured["Discounts"] / sales_structured["Gross Sales"]
sales_structured["Discount %"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 695    0.15
# 696    0.15
# 697    0.15
# 698    0.15
# 699    0.15
# Name: Discount %, Length: 700, dtype: float64

# %% [markdown]
# ### Add a conditional column to dataframe when we have 2 options (Yes/No, True/False, etc.)

# %%
sales_structured['Valued Sale'] = np.where(sales_structured['Discount Band']=='High', True, False)
sales_structured['Valued Sale']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 695    False
# 696    False
# 697    False
# 698    False
# 699    False
# Name: Valued Sale, Length: 700, dtype: bool

# %% [markdown]
# ### Add a conditional column to dataframe when we have multiple options

# %%
conditions = [
    (sales_structured['Country'] == 'Mexico'),
    (sales_structured['Country'] == 'Canada'),
    (sales_structured['Country'] == 'France'),]
choices = ['Third World', 'Developed','European']
# sales_structured['class'] = np.select(conditions, choices)
sales_structured['class'] = np.select(conditions, choices, default='Other')
sales_structured["class"].unique()
# Out:
# array(['Developed', 'Other', 'European', 'Third World'], dtype=object)

# %% [markdown]
# ### Add rows to dataframe

# %%
# Method 1 from a list or lists
s1 = pd.Series([1, 2, 3])
s2 = pd.Series([4, 5, 6])
cols =  ["A", "B", "C"]

test_df = pd.DataFrame([list(s1), list(s2)],  columns =  cols)

# %%
test_df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
test_df.loc[len(test_df.index)] = [9,9,9] 
test_df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  9  9  9

# %% [markdown]
# ### Move columns within a dataframe

# %%
sales_structured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount Band        700 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           700 non-null    int64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            647 non-null    float64
#  9   Sales                700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               695 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %%
sales_structured = sales_structured[['Date',
'Year',
'Month Number',
'Month Name',
'Segment',
'Country',
'Product',
'Discount Band',
'Type of Sales',
'Valued Sale',
'Sale Price',
'Gross Sales',
'Discounts',
'Discount %',
'Sales',
'COGS',
'Profit',
'Units Sold',
'Manufacturing Price',
'class']]

# %%
sales_structured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 700 non-null    datetime64[ns]
#  1   Year                 700 non-null    int64
#  2   Month Number         700 non-null    int64
#  3   Month Name           700 non-null    object
#  4   Segment              700 non-null    object
#  5   Country              700 non-null    object
#  6   Product              700 non-null    object
#  7   Discount Band        700 non-null    object
#  8   Type of Sales        700 non-null    object
#  9   Valued Sale          700 non-null    bool
#  10  Sale Price           700 non-null    int64
#  11  Gross Sales          700 non-null    float64
#  12  Discounts            647 non-null    float64
#  13  Discount %           647 non-null    float64
#  14  Sales                700 non-null    float64
# ...

# %% [markdown]
# ### Delete columns from a dataframe

# %%
# Method 1: Using drop. inplace=True means the operation would work on the original object. axis=1 means we are dropping the column, not the row.
sales_structured.drop('class', inplace=True, axis=1)
sales_structured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 700 non-null    datetime64[ns]
#  1   Year                 700 non-null    int64
#  2   Month Number         700 non-null    int64
#  3   Month Name           700 non-null    object
#  4   Segment              700 non-null    object
#  5   Country              700 non-null    object
#  6   Product              700 non-null    object
#  7   Discount Band        700 non-null    object
#  8   Type of Sales        700 non-null    object
#  9   Valued Sale          700 non-null    bool
#  10  Sale Price           700 non-null    int64
#  11  Gross Sales          700 non-null    float64
#  12  Discounts            647 non-null    float64
#  13  Discount %           647 non-null    float64
#  14  Sales                700 non-null    float64
# ...

# %%
# Method 2. Using del
# del sales_structured['Discount %']

# %%
# Method 3. Using pop(). Unlike the other two methods, this function would return the column.
# sales_structured.pop('Discount %')

# %% [markdown]
# ### Duplicate columns within a dataframe

# %%
sales_structured['COGS_Duplicate'] = sales_structured['COGS']
sales_structured[["COGS", "COGS_Duplicate"]]
# Out:
#          COGS  COGS_Duplicate
# 0     16185.0         16185.0
# 1     13210.0         13210.0
# 2     21780.0         21780.0
# 3      8880.0          8880.0
# 4     24700.0         24700.0
# ..        ...             ...
# 695  618750.0        618750.0
# 696  136500.0        136500.0
# 697    6840.0          6840.0
# 698    3615.0          3615.0
# 699    5418.0          5418.0
#
# [700 rows x 2 columns]

# %%
sales_structured.head(5)
# Out:
#         Date  Year  Month Number Month Name     Segment  Country      Product  \
# 0 2014-01-01  2014             1   January   Government   Canada   Carretera
# 1 2014-01-01  2014             1   January   Government  Germany   Carretera
# 2 2014-06-01  2014             6      June    Midmarket   France   Carretera
# 3 2014-06-01  2014             6      June    Midmarket  Germany   Carretera
# 4 2014-06-01  2014             6      June    Midmarket   Mexico   Carretera
#
#   Discount Band Type of Sales  Valued Sale  Sale Price  Gross Sales  \
# 0         None          Store        False          20      32370.0
# 1         None          Store        False          20      26420.0
# 2         None          Store        False          15      32670.0
# 3         None          Store        False          15      13320.0
# 4         None          Store        False          15      37050.0
#
#    Discounts  Discount %    Sales     COGS   Profit  Units Sold  \
# ...

# %% [markdown]
# ### Split column by delimiter into multiple columns

# %%
# I will duplicate the date column first
sales_structured['Date_Copy'] = sales_structured['Date']

# %%
# I will change the data type from datetime to object
sales_structured = sales_structured.astype({"Date_Copy": 'str'}, errors='ignore')

# %%
sales_structured
# Out:
#           Date  Year  Month Number  Month Name           Segment  \
# 0   2014-01-01  2014             1    January         Government
# 1   2014-01-01  2014             1    January         Government
# 2   2014-06-01  2014             6       June          Midmarket
# 3   2014-06-01  2014             6       June          Midmarket
# 4   2014-06-01  2014             6       June          Midmarket
# ..         ...   ...           ...         ...               ...
# 695 2014-03-01  2014             3      March     Small Business
# 696 2014-10-01  2014            10    October     Small Business
# 697 2014-02-01  2014             2   February         Government
# 698 2014-04-01  2014             4      April         Government
# 699 2014-05-01  2014             5        May   Channel Partners
#
#                       Country      Product Discount Band Type of Sales  \
# 0                      Canada   Carretera          None          Store
# ...

# %%
# Performing the split 
sales_structured[['SP_Year', 'SP_Month', 'SP_Day']] = sales_structured['Date_Copy'].str.split('-', expand=True)
sales_structured
# Out:
#           Date  Year  Month Number  Month Name           Segment  \
# 0   2014-01-01  2014             1    January         Government
# 1   2014-01-01  2014             1    January         Government
# 2   2014-06-01  2014             6       June          Midmarket
# 3   2014-06-01  2014             6       June          Midmarket
# 4   2014-06-01  2014             6       June          Midmarket
# ..         ...   ...           ...         ...               ...
# 695 2014-03-01  2014             3      March     Small Business
# 696 2014-10-01  2014            10    October     Small Business
# 697 2014-02-01  2014             2   February         Government
# 698 2014-04-01  2014             4      April         Government
# 699 2014-05-01  2014             5        May   Channel Partners
#
#                       Country      Product Discount Band Type of Sales  \
# 0                      Canada   Carretera          None          Store
# ...

# %% [markdown]
# ### Add index to dataframe

# %%
# sales_structured.set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False)

# %% [markdown]
# *   `keys`: It takes a single or list of column labels to set as an index. It also takes a list of new labels as input.
# *   `drop`: It is a flag to specify if columns to be used as the new index should be deleted From DataFrame or not.
# By default value is `True`, i.e., assign the column as an index and delete it.
# *   `append`: It is a flag to specify whether to append columns to the existing index. By default, it is `False`, i.e., it replaces the current index rather than appending.
# *   `inplace`: It is used to specify whether to return a new DataFrame or update an existing one. It is a boolean flag with default False.
# *   `verify_integrity`: It is a boolean flag,
# – If `True`, then it checks the new index for duplicates and throws ValueError.
# – If `False`, then it defers the check until necessary. **Note:** Setting to `False` will improve the performance of this method.

# %% [markdown]
# ### Combine two tables with similar structure

# %%
# sales_combined = pd.concat([sales_structured, sales_structured2], axis=0)

# %%
# Adding keys will add an identifier for each table 
# air_quality_ = pd.concat([air_quality_pm25, air_quality_no2], keys=["PM25", "NO2"])

# %% [markdown]
# ### Join tables using a common identifier

# %%
# In this examples, both tables have the column location in common which is used as a key to combine the information
# air_quality = pd.merge(air_quality, stations_coord, how="left", on="location")

# This merge happens when they key has a different name in the second table
# air_quality = pd.merge(air_quality, air_quality_parameters, how='left', left_on='parameter', right_on='id')

# More information here: https://pandas.pydata.org/docs/user_guide/merging.html#merging

# %% [markdown]
# ### Transpose Non-square DataFrame with mixed dtypes

# %%
sales_transposed = sales_structured.T # or sales_structured.transpose()
sales_transposed
# Out:
#                                      0                    1    \
# Date                 2014-01-01 00:00:00  2014-01-01 00:00:00
# Year                                2014                 2014
# Month Number                           1                    1
# Month Name                      January              January
# Segment                       Government           Government
# Country                           Canada              Germany
# Product                       Carretera            Carretera
# Discount Band                      None                 None
# Type of Sales                      Store                Store
# Valued Sale                        False                False
# Sale Price                            20                   20
# Gross Sales                      32370.0              26420.0
# Discounts                            NaN                  NaN
# Discount %                           NaN                  NaN
# ...

# %% [markdown]
# ### Select 1 or more columns

# %%
# Selecting 1 column
# ages = titanic["Age"]

# Selecting multiple columns
# age_sex = titanic[["Age", "Sex"]]

# %% [markdown]
# ### Select specific columns and filter by 1 condition

# %%
# df2 = df1[["Column1","Column2","Column3"]][df1["Column4"]=="Some text"]
# df2

# %% [markdown]
# ### Filter specific rows from a DataFrame

# %%
# above_35 = df[df["Age"] > 35]

# Using the following approach will return a True/False column
# titanic["Age"] > 35

# %% [markdown]
# ### Filter dataframe by date

# %%
sales_structured[sales_structured['Date'] == '2014-01-01']
# Out:
#           Date  Year  Month Number Month Name           Segment  \
# 0   2014-01-01  2014             1   January         Government
# 1   2014-01-01  2014             1   January         Government
# 31  2014-01-01  2014             1   January         Government
# 53  2014-01-01  2014             1   January         Government
# 155 2014-01-01  2014             1   January     Small Business
# 175 2014-01-01  2014             1   January   Channel Partners
# 188 2014-01-01  2014             1   January         Government
# 214 2014-01-01  2014             1   January         Government
# 231 2014-01-01  2014             1   January         Government
# 252 2014-01-01  2014             1   January          Midmarket
# 253 2014-01-01  2014             1   January          Midmarket
# 273 2014-01-01  2014             1   January         Government
# 299 2014-01-01  2014             1   January         Enterprise
# 315 2014-01-01  2014             1   January   Channel Partners
# ...

# %% [markdown]
# ### Filtering using multiple conditions

# %%
# Method 1
# class_23 = titanic[(titanic["Pclass"] == 2) | (titanic["Pclass"] == 3)]
# You can not use or/and but need to use the or operator | and the and operator &.

# Method 2. Using 
# class_23 = titanic[titanic["Pclass"].isin([2, 3])]

# %% [markdown]
# ### Excluding not NA

# %%
# age_no_na = titanic[titanic["Age"].notna()]

# %% [markdown]
# ### Select specific rows and columns from a DataFrame

# %%
# When using loc/iloc, the part before the comma is the rows you want, and the part after the comma is the columns you want to select.
# When using the column names, row labels or a condition expression, use the loc operator in front of the selection brackets 
# adult_names = titanic.loc[titanic["Age"] > 35, "Name"]


# When specifically interested in certain rows and/or columns based on their position in the table, use the iloc operator in front of the selection brackets
# Rows 10 till 25 and columns 3 to 5.
# titanic.iloc[9:25, 2:5]

# %% [markdown]
# ### Replace character/s under the entire DataFrame

# %%
# df = df.replace('old character','new character', regex=True)

# %% [markdown]
# ### Format currency

# %%
# As in a pivot table, segment would be in the rows Sales in the values and the calculation is sum()
# Method 1
sales_structured[["Segment","Sales"]].groupby("Segment").sum().style.format('${0:,.2f}')

# Method 2 returns a series and cannot be formatted
# sales_structured.groupby("Segment")["Sales"].agg("sum")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8ce52_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Segment</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ce52_level0_row0" class="row_heading level0 row0" >Channel Partners</th>
#       <td id="T_8ce52_row0_col0" class="data row0 col0" >$1,800,593.64</td>
#     </tr>
#     <tr>
#       <th id="T_8ce52_level0_row1" class="row_heading level0 row1" >Enterprise</th>
#       <td id="T_8ce52_row1_col0" class="data row1 col0" >$19,611,694.38</td>
#     </tr>
#     <tr>
#       <th id="T_8ce52_level0_row2" class="row_heading level0 row2" >Government</th>
#       <td id="T_8ce52_row2_col0" class="data row2 col0" >$52,504,260.68</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Format percentage

# %%
sales_structured[["Country","Discount %"]].groupby("Country").mean().style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e36ee_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Discount %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e36ee_level0_row0" class="row_heading level0 row0" >Canada</th>
#       <td id="T_e36ee_row0_col0" class="data row0 col0" >8.32%</td>
#     </tr>
#     <tr>
#       <th id="T_e36ee_level0_row1" class="row_heading level0 row1" >France</th>
#       <td id="T_e36ee_row1_col0" class="data row1 col0" >7.58%</td>
#     </tr>
#     <tr>
#       <th id="T_e36ee_level0_row2" class="row_heading level0 row2" >Germany</th>
#       <td id="T_e36ee_row2_col0" class="data row2 col0" >7.62%</td>
#     </tr>
#     <tr>
#       <th id="T_e36ee_level0_row3" class="row_heading level0 row3" >Mexico</th>
# ...

# %% [markdown]
# ### Formatting 2 columns

# %%
summary = sales_structured[["Country","Sales","Discount %"]].groupby("Country").agg(['sum','mean'])
summary
#format_dict = {'Sales':'${0:,.0f}', 'Discount %': '{:.2%}'}
#summary.style.format(format_dict) #.hide_index()
# Out:
#                                 Sales                Discount %
#                                   sum           mean        sum      mean
# Country
# Canada                    24887654.89  177768.963500  10.650000  0.083203
# France                    24354172.29  173958.373500   9.930000  0.075802
# Germany                   23505340.82  167895.291571   9.450000  0.076210
# Mexico                    20949352.11  149638.229357  11.010000  0.083409
# United States of America  25029830.18  178784.501286  10.290001  0.077955

# %% [markdown]
# ### Group by 1 column

# %%
# Will not work for a 1-colum calculation 
sales_structured[["Country","Profit"]].groupby("Country").sum().style.format('${0:,.2f}').highlight_max(color='navy')
# Out:
# <style type="text/css">
# #T_2be8b_row1_col0 {
#   background-color: navy;
# }
# </style>
# <table id="T_2be8b_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Profit</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2be8b_level0_row0" class="row_heading level0 row0" >Canada</th>
#       <td id="T_2be8b_row0_col0" class="data row0 col0" >$3,529,228.89</td>
#     </tr>
#     <tr>
#       <th id="T_2be8b_level0_row1" class="row_heading level0 row1" >France</th>
#       <td id="T_2be8b_row1_col0" class="data row1 col0" >$3,781,020.79</td>
#     </tr>
#     <tr>
#       <th id="T_2be8b_level0_row2" class="row_heading level0 row2" >Germany</th>
#       <td id="T_2be8b_row2_col0" class="data row2 col0" >$3,680,388.82</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Group by multiple columns

# %%
format_dict = {'Sales':'${0:,.0f}', 'Units Sold': '{0:,.0f}'}
sales_structured[["Country","Segment","Units Sold","Sales"]].groupby(["Country","Segment"]).sum().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bf02f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Units Sold</th>
#       <th class="col_heading level0 col1" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="index_name level1" >Segment</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf02f_level0_row0" class="row_heading level0 row0" rowspan="5">Canada</th>
#       <th id="T_bf02f_level1_row0" class="row_heading level1 row0" >Channel Partners</th>
#       <td id="T_bf02f_row0_col0" class="data row0 col0" >44,062</td>
#       <td id="T_bf02f_row0_col1" class="data row0 col1" >$491,164</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Pivot format and columns

# %%
# Method 1: using the pivot_table method
sales_structured.pivot_table(index='Country', columns='Segment', values='Units Sold', aggfunc='sum').style.format('{0:,.0f}') #passing the format_dict does not work here
# Out:
# <style type="text/css">
# </style>
# <table id="T_4a182_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Segment</th>
#       <th class="col_heading level0 col0" >Channel Partners</th>
#       <th class="col_heading level0 col1" >Enterprise</th>
#       <th class="col_heading level0 col2" >Government</th>
#       <th class="col_heading level0 col3" >Midmarket</th>
#       <th class="col_heading level0 col4" >Small Business</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a182_level0_row0" class="row_heading level0 row0" >Canada</th>
#       <td id="T_4a182_row0_col0" class="data row0 col0" >44,062</td>
# ...

# %%
# Method 2: using pandas
pd.pivot_table(sales_structured, index='Country',  columns='Segment', values='Units Sold', aggfunc='sum').style.format("{0:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae555_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Segment</th>
#       <th class="col_heading level0 col0" >Channel Partners</th>
#       <th class="col_heading level0 col1" >Enterprise</th>
#       <th class="col_heading level0 col2" >Government</th>
#       <th class="col_heading level0 col3" >Midmarket</th>
#       <th class="col_heading level0 col4" >Small Business</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae555_level0_row0" class="row_heading level0 row0" >Canada</th>
#       <td id="T_ae555_row0_col0" class="data row0 col0" >44,062</td>
# ...

# %%
# Adding another dimension or index
sales_structured.pivot_table(index=['Country','Discount Band'], columns='Segment', values='Units Sold', aggfunc='sum').style.format('{0:,.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4b0ac_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Segment</th>
#       <th class="col_heading level0 col0" >Channel Partners</th>
#       <th class="col_heading level0 col1" >Enterprise</th>
#       <th class="col_heading level0 col2" >Government</th>
#       <th class="col_heading level0 col3" >Midmarket</th>
#       <th class="col_heading level0 col4" >Small Business</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="index_name level1" >Discount Band</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Combining aggregate functions

# %%
# Method 1: using a pivot table
sales_structured.pivot_table(index="Country", columns=None, values=["Sales","Profit"], aggfunc={'Sales':np.sum, 'Profit':np.mean}).style.format('${0:,.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c002a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Profit</th>
#       <th class="col_heading level0 col1" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c002a_level0_row0" class="row_heading level0 row0" >Canada</th>
#       <td id="T_c002a_row0_col0" class="data row0 col0" >$25,209</td>
#       <td id="T_c002a_row0_col1" class="data row0 col1" >$24,887,655</td>
#     </tr>
#     <tr>
#       <th id="T_c002a_level0_row1" class="row_heading level0 row1" >France</th>
#       <td id="T_c002a_row1_col0" class="data row1 col0" >$27,202</td>
#       <td id="T_c002a_row1_col1" class="data row1 col1" >$24,354,172</td>
#     </tr>
#     <tr>
# ...

# %%
# Method 2: using the group by approach
sales_structured[["Country","Profit","Sales"]].groupby("Country").agg({'Profit':np.mean, 'Sales':np.sum}).style.format('${0:,.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b05e2_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Profit</th>
#       <th class="col_heading level0 col1" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b05e2_level0_row0" class="row_heading level0 row0" >Canada</th>
#       <td id="T_b05e2_row0_col0" class="data row0 col0" >$25,209</td>
#       <td id="T_b05e2_row0_col1" class="data row0 col1" >$24,887,655</td>
#     </tr>
#     <tr>
#       <th id="T_b05e2_level0_row1" class="row_heading level0 row1" >France</th>
#       <td id="T_b05e2_row1_col0" class="data row1 col0" >$27,202</td>
#       <td id="T_b05e2_row1_col1" class="data row1 col1" >$24,354,172</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Using join()

# %%
# df.join(other, lsuffix='_caller', rsuffix='_other')
# More info here: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html?highlight=join#pandas.DataFrame.join

# %% [markdown]
# ### Sorting columns by values in dataframe

# %%
sales_structured.sort_values("Country", ascending=False)
# Out:
#           Date  Year  Month Number   Month Name           Segment  \
# 699 2014-05-01  2014             5         May   Channel Partners
# 301 2013-10-01  2013            10     October         Government
# 535 2013-09-01  2013             9   September         Government
# 123 2014-10-01  2014            10     October         Government
# 628 2014-10-01  2014            10     October     Small Business
# ..         ...   ...           ...          ...               ...
# 595 2014-10-01  2014            10     October         Government
# 202 2013-09-01  2013             9   September         Government
# 195 2014-09-01  2014             9   September         Government
# 194 2014-09-01  2014             9   September          Midmarket
# 0   2014-01-01  2014             1     January         Government
#
#                       Country      Product Discount Band Type of Sales  \
# 699  United States of America         VTT          High          Store
# ...
